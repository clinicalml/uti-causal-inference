# %%
## This notebook reads the in_name df from the database, and writes to the out_name database
in_name= 'manuscript_covariates_0_final'
out_name = 'manuscript_covariates_1_final'

# %%
import sys
import pickle
import requests
import json
sys.path.append( '..' )
import psycopg2
import pandas as pd
import numpy
#import sparse
import config
import sys
import time
import importlib
#
import datetime
import pandas as pd
import numpy as np
import scipy.sparse
import matplotlib.pyplot as plt

# %%
import sparse
import Utils.dbutils as dbutils
import Utils.data_utils as data_utils
import Generators.CohortGenerator as CohortGenerator
import Generators.FeatureGenerator as FeatureGenerator
import config
local_imports = (
    dbutils,
    data_utils,
    CohortGenerator,
    FeatureGenerator,
    config
)
for i in local_imports:
    i = importlib.reload(i)

# database connection
username = config.PG_USERNAME
password = config.PG_PASSWORD
database_name = config.DB_NAME

#config_path = 'postgresql://{username}:{password}@{database_name}'.format(
config_path = 'postgresql://{database_name}'.format(database_name = database_name)


    #username = username,
    #password = password,
   # database_name = database_name
#)

# schemas 
schema_name = 'eol_test_eheal' # all created tables will be created using this schema

# caching
reset_schema = False # if true, rebuild all data from scratch

# set up database, reset schemas as needed
db = dbutils.Database(config_path, schema_name)
if reset_schema:
    db.execute(
        'drop schema if exists {} cascade'.format(schema_name)
    )
db.execute(
    'create schema if not exists {}'.format(schema_name)
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-d7f904968c9f> in <module>()
# ----> 1 import sparse
#       2 import Utils.dbutils as dbutils
#       3 import Utils.data_utils as data_utils
#       4 import Generators.CohortGenerator as CohortGenerator
#       5 import Generators.FeatureGenerator as FeatureGenerator
#
# ImportError: No module named sparse

# %%
# set input
username='cdm_6871_21'
password='MLHC2021'
database_name = 'omop_v6'
conn_string = "dbname="+database_name + " host=/var/run/postgresql"
conn=psycopg2.connect(conn_string)

sql_cmd = 'select * from cdm_6871_21.{}'.format(in_name)
covariate_df =pd.read_sql(sql_cmd, conn)

# %% [markdown]
# ## Add provider info

# %%
'''
SELECT provider.provider_id, specialty_concept_id, concept_name, npi
FROM (SELECT * FROM cdm_6871_21.provider
        WHERE provider_id IN
            (SELECT visit_provider_id FROM cdm_6871_21.c{in_name})) as provider
JOIN (SELECT concept_id, concept_name FROM cdm_6871_21.concept) as concept
ON provider.specialty_concept_id=concept.concept_id
GROUP BY provider.provider_id, provider.specialty_concept_id, concept.concept_name, provider.npi
'''.format(in_name=in_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b756483d544> in <module>
#       7 ON provider.specialty_concept_id=concept.concept_id
#       8 GROUP BY provider.provider_id, provider.specialty_concept_id, concept.concept_name, provider.npi
# ----> 9 '''.format(in_name= in_name)
#
# NameError: name 'in_name' is not defined

# %%
# %%time


# visit provider info
sql_cmd = '''
SELECT provider.provider_id, specialty_concept_id, concept_name, npi
FROM (SELECT * FROM cdm_6871_21.provider
        WHERE provider_id IN
            (SELECT visit_provider_id FROM cdm_6871_21.c{in_name})) as provider
JOIN (SELECT concept_id, concept_name FROM cdm_6871_21.concept) as concept
ON provider.specialty_concept_id=concept.concept_id
GROUP BY provider.provider_id, provider.specialty_concept_id, concept.concept_name, provider.npi
'''.format(in_name= in_name1)
provider_visit = pd.read_sql(sql_cmd, conn)
provider_visit.head()
print(len(provider_visit))
# Out:
# 9585
# CPU times: user 28 ms, sys: 4 ms, total: 32 ms
# Wall time: 1.43 s

# %%
# %%time 
# durg provider infor
sql_cmd = '''
SELECT provider.provider_id, specialty_concept_id, concept_name, npi
FROM (SELECT * FROM cdm_6871_21.provider
        WHERE provider_id IN
            (SELECT provider_id FROM cdm_6871_21.cohort_manuscript_updated_treatments)) as provider
JOIN (SELECT concept_id, concept_name FROM cdm_6871_21.concept) as concept
ON provider.specialty_concept_id=concept.concept_id
GROUP BY provider.provider_id, provider.specialty_concept_id, concept.concept_name, provider.npi
'''
provider = pd.read_sql(sql_cmd, conn)
provider.head()
print(len(provider))
# Out:
# 14235
# CPU times: user 40 ms, sys: 0 ns, total: 40 ms
# Wall time: 1.21 s

# %%
provider_visit = provider_visit.rename(columns = {'specialty_concept_id': 'visit_specialty_concept_id','provider_id':'visit_provider_id','npi':'visit_npi','concept_name':'visit_concept_name'})
provider = provider.rename(columns = {'npi':'drug_npi'})

# %%
#vtemp_visit = v12.join(provider_visit[['visit_provider_id', 'visit_specialty_concept_id', 'visit_concept_name','visit_npi']].set_index('visit_provider_id'), on='visit_provider_id')
vtemp_visit = covariate_df.join(provider_visit[['visit_provider_id', 'visit_specialty_concept_id', 'visit_concept_name','visit_npi']].set_index('visit_provider_id'), on='visit_provider_id')
vtemp_visit['visit_specialty_concept_id'].fillna(0, inplace = True)

vtemp = vtemp_visit.join(provider[['provider_id', 'specialty_concept_id', 'concept_name','drug_npi']].set_index('provider_id'), on='provider_id')
vtemp['specialty_concept_id'].fillna(0, inplace = True)

# %%
temp = vtemp[['npi','drug_npi','visit_npi','condition_occurrence_id','person_id','visit_provider_id','provider_id', 'visit_specialty_concept_id', 'specialty_concept_id', 'visit_concept_name','concept_name']]

# %%
temp1 = temp.assign(provider_specialty_available = False)
temp1.provider_specialty_available = (~(temp1.concept_name=='No matching concept')&~(temp1.provider_id==-1))

temp1 = temp1.assign(visit_provider_specialty_available = False)
temp1.visit_provider_specialty_available = (~(temp1.visit_concept_name=='No matching concept')&~(temp1.visit_provider_id==-1))
provider_table = temp1.copy()

# %% [markdown]
# ## Query NPI database and Pickle

# %%
error_index = []
error_condition = []
not_found = []

provider_visit_dict = {}
count = 0
for n in provider_table.visit_npi.unique():
    count+=1
    if count%200==0:
        print(count/provider_table.visit_npi.nunique())
    try:
        r = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')
        results_text =json.loads( r.text)
        try: 
            provider_visit_dict[n] = results_text["results"][0]["taxonomies"]
        except:
            not_found.append(n)          
    except:
        error_condition.append(n)
        error_index.append(n)
print (f'Number of not found: {len(not_found)}')
# Out:
# 0.018138944313440958
# 0.036277888626881916
# 0.05441683294032287
# 0.07255577725376383
# 0.09069472156720479
# 0.10883366588064575
# 0.1269726101940867
# 0.14511155450752766
# 0.16325049882096862
# 0.18138944313440958
# 0.19952838744785054
# 0.2176673317612915
# 0.23580627607473245
# 0.2539452203881734
# 0.27208416470161434
# 0.2902231090150553
# 0.30836205332849626
# 0.32650099764193724
# 0.34463994195537817
# 0.36277888626881916
# 0.3809178305822601
# 0.39905677489570107
# 0.417195719209142
# 0.435334663522583
# 0.4534736078360239
# 0.4716125521494649
# 0.48975149646290583
# 0.5078904407763468
# 0.5260293850897878
# 0.5441683294032287
# 0.5623072737166697
# 0.5804462180301106
# 0.5985851623435516
# 0.6167241066569925
# 0.6348630509704335
# 0.6530019952838745
# 0.6711409395973155
# 0.6892798839107563
# 0.7074188282241973
# 0.7255577725376383
# 0.7436967168510793
# 0.7618356611645202
# 0.7799746054779612
# 0.7981135497914021
# 0.8162524941048431
# 0.834391438418284
# 0.852530382731725
# 0.870669327045166
# 0.888808271358607
# 0.9069472156720478
# 0.9250861599854888
# 0.9432251042989298
# 0.9613640486123708
# 0.9795029929258117
# 0.9976419372392527
# Number of not found: 116

# %%
import pickle
pickle.dump(provider_visit_dict, open('provider_visit_dict.p','wb'))
pickle.dump(not_found, open('provider_visit_npis_not_found.p','wb'))

# %%
# Load Drug NPI information
error_index_drug = []
error_condition_drug = []
not_found_drug = []

#provider_drug_dict = {}
count = 0
for n in provider_table.drug_npi.unique():
    count+=1
    if count%600==0:
        print(count/provider_table.drug_npi.nunique())
    try:
        r = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')
        results_text =json.loads( r.text)
        try: 
            provider_drug_dict[n] = results_text["results"][0]["taxonomies"]
        except:
            not_found_drug.append(n)          
    except:
        error_condition_drug.append(n)
        error_index_drug.append(n)
import pickle
pickle.dump(provider_drug_dict, open('provider_drug_dict.p','wb'))
pickle.dump(not_found_drug, open('provider_drug_npis_not_found.p','wb'))
# Out:
# 0.05265467310223782
# 0.10530934620447564
# 0.15796401930671347
# 0.21061869240895129
# 0.26327336551118913
# 0.31592803861342694
# 0.36858271171566476
# 0.42123738481790257
# 0.4738920579201404
# 0.5265467310223783
# 0.5792014041246161
# 0.6318560772268539
# 0.6845107503290917
# 0.7371654234313295
# 0.7898200965335673
# 0.8424747696358051
# 0.895129442738043
# 0.9477841158402808

# %% [markdown]
# ## Load pickle and add information to covariate table

# %%
provider_visit_dict =pickle.load(open('provider_visit_dict.p','rb'))
provider_drug_dict =pickle.load(open('provider_drug_dict.p','rb'))

# %%
# Drug
provider_table = provider_table.assign(visit_npi_desc = '')
provider_table = provider_table.assign(drug_npi_desc = '')
provider_table = provider_table.assign(npi_same = False)

error_index = []
error_condition = []
not_found = []
no_primary_taxonomy_found_drug = []
no_primary_taxonomy_found_visit = []
flag = False
count = 0
multiple = []
for idx,row in provider_table.iterrows():
    n = row.drug_npi
    if str(n) !='nan':
        try:
            taxonomies =provider_drug_dict[n]
            if len(taxonomies)==1:  
                provider_table.loc[idx,'drug_npi_desc'] = taxonomies[0]["desc"]
            else:
                num_tax = 0
                for tax in taxonomies:
                    
                    multiple.append(n)
                    if tax['primary']==True:
                        provider_table.loc[idx,'drug_npi_desc'] = tax["desc"]
                        num_tax +=1
                        flag = True
                if num_tax>1:
                    print(n)
                if flag ==False:
                    no_primary_taxonomy_found_drug.append(n)
                flag = False
        except:
            provider_table.loc[idx,'drug_npi_desc'] = None
    n = row.visit_npi
    if str(n) != 'nan' and n != None:
        try:
            taxonomies =provider_visit_dict[n]
            
            if len(taxonomies)==1:  
                provider_table.loc[idx,'visit_npi_desc'] = taxonomies[0]["desc"]
            else:
                for tax in taxonomies:
                    if tax['primary']==True:
                        provider_table.loc[idx,'visit_npi_desc'] = tax["desc"]
                        flag = True
                        
                if flag ==False:
                    no_primary_taxonomy_found_visit.append(n)
                flag = False
            if row.drug_npi ==row.visit_npi:
                provider_table.loc[idx,'npi_same'] = True    
            count +=1
        except:
            provider_table.loc[idx,'visit_npi_desc'] = None

        if count%5000 ==0:
            print(count/len(provider_table))
# Out:
# 0.07298950410930909
# 0.14597900821861817
# 0.21896851232792724
# 0.29195801643723635
# 0.3649475205465454
# 0.4379370246558545
# 0.5109265287651635
# 0.5839160328744727
# 0.6569055369837817
# 0.7298950410930908
# 0.8028845452023999

# %%
provider_table['drug_npi_desc'].value_counts()
# Out:
# Family Medicine                                                         18583
#                                                                         15489
# Internal Medicine                                                        9769
# Nurse Practitioner Family                                                4325
# Emergency Medicine                                                       4136
#                                                                         ...
# Registered Nurse Pediatrics                                                 1
# Physical Medicine & Rehabilitation Pediatric Rehabilitation Medicine        1
# Clinic/Center Health Services                                               1
# Allergy & Immunology Allergy                                                1
# Surgery Plastic and Reconstructive Surgery                                  1
# Name: drug_npi_desc, Length: 170, dtype: int64

# %%
covariate_df_new = covariate_df.join(provider_table[['condition_occurrence_id', 'drug_npi_desc']].set_index('condition_occurrence_id'), on='condition_occurrence_id')

# %% [markdown]
# # old

# %%
'''provider_table = provider_table.assign(visit_npi_desc = '')
provider_table = provider_table.assign(drug_npi_desc = '')
provider_table = provider_table.assign(npi_same = False)

error_index = []
error_condition = []
not_found = []
for idx,row in provider_table.iterrows():
    if idx>-1:
        n = row.drug_npi
        try:
            r = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')
            results_text =json.loads( r.text)
            try: 
                provider_table.loc[idx,'drug_npi_desc'] = results_text["results"][0]["taxonomies"][0]["desc"]
            except:
                not_found.append(n)
            n = row.visit_npi
            r = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')
            results_text =json.loads( r.text)
            try: 
                provider_table.loc[idx,'visit_npi_desc'] = results_text["results"][0]["taxonomies"][0]["desc"]
            except:
                not_found.append(n)
            if row.drug_npi ==row.visit_npi:
                provider_table.loc[idx,'npi_same'] = True
            if idx%500==0:
                print(idx/83000)
        except:
            error_condition.append(row.condition_occurrence_id)
            error_index.append(idx)
print (f'Number of not found: {len(not_found)}')

'''

# %%
'''provider_table.to_sql("provider_v12",con=db.engine, if_exists="replace", schema="cdm_6871_21")
db.execute("GRANT SELECT ON TABLE cdm_6871_21.provider_v12 TO cdm_6871_21;")



username='cdm_6871_21'
password='MLHC2021'
database_name = 'omop_v6'
conn_string = "dbname="+database_name + " host=/var/run/postgresql"
conn=psycopg2.connect(conn_string)

sql_command = "select * from cdm_6871_21.provider_v12;"
provider_table = pd.read_sql(sql_command,conn)
v12_new = covariate_df.join(provider_table[['condition_occurrence_id', 'drug_npi_desc']].set_index('condition_occurrence_id'), on='condition_occurrence_id')



'''
# Out:
# Executed 1 SQLs

# %% [markdown]
# ### One hot encoding

# %%
covariate_df_new = covariate_df_new.assign(provider_specialty_available = False)
covariate_df_new.provider_specialty_available = (~(covariate_df_new['drug_npi_desc']==''))

# %%
covariate_df_new.provider_specialty_available.value_counts()
# Out:
# True     53014
# False    15489
# Name: provider_specialty_available, dtype: int64

# %%
covariate_df_new.drug_npi_desc.value_counts().tail(180).head(20)
# Out:
# Family Medicine                         18583
#                                         15489
# Internal Medicine                        9769
# Nurse Practitioner Family                4325
# Emergency Medicine                       4136
# General Acute Care Hospital              2854
# Obstetrics & Gynecology                  2657
# Urology                                  1804
# Nurse Practitioner                        679
# Nurse Practitioner Adult Health           649
# Physician Assistant                       587
# Non-Pharmacy Dispensing Site              582
# Obstetrics & Gynecology Gynecology        537
# Pediatrics                                485
# Hospitalist                               391
# Physician Assistant Medical               371
# Specialist                                354
# Internal Medicine Geriatric Medicine      301
# General Practice                          246
# Family Medicine Sports Medicine           193
# Name: drug_npi_desc, dtype: int64

# %%
provider_table.npi_same.value_counts()
# Out:
# False    47773
# True     20730
# Name: npi_same, dtype: int64

# %%
covariate_df_new1 = covariate_df_new.copy()

# %%
# %%time
covariate_df_new1 = covariate_df_new1.assign(drug_npi_desc_grouped = '')
none_count = 0
i=0
for idx, row in covariate_df_new1.iterrows():
    if row.drug_npi_desc == None:
        none_count+=1
    else:
        desc = row.drug_npi_desc.lower()
        if 'nurse' in desc or 'physician assistant' in desc:
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'advanced_specialist_group'
        elif ('family' in desc and not ('planning' in desc or 'marriage' in desc) ) or  ('general practice' in desc and not 'dentist' in desc):
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'family_medicine_group'
        elif 'internal medicine' == desc or 'internal medicine geriatric medicine' == desc:
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'internal_medicine_group'
        elif 'emergency' in desc or 'acute' in desc or 'hospital' in desc:
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'emergency/acute_group'
        elif 'urology' in desc and not('neurology' in desc):
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'urology_group'
        elif 'gynecology' in desc or 'OBG' in desc or 'midwife' in desc:
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'OBGYN_group'
        elif len(desc)>0 :
            covariate_df_new1.loc[idx,'drug_npi_desc_grouped'] = 'other_group'
    if i %3000 ==0:
        print(i/len(covariate_df_new1))
        
    i = i+1
# Out:
# 0.0
# 0.04379370246558545
# 0.0875874049311709
# 0.13138110739675635
# 0.1751748098623418
# 0.21896851232792724
# 0.2627622147935127
# 0.30655591725909814
# 0.3503496197246836
# 0.39414332219026904
# 0.4379370246558545
# 0.48173072712143994
# 0.5255244295870254
# 0.5693181320526108
# 0.6131118345181963
# 0.6569055369837817
# 0.7006992394493672
# 0.7444929419149526
# 0.7882866443805381
# 0.8320803468461235
# 0.875874049311709
# 0.9196677517772944
# 0.9634614542428799
# CPU times: user 55 s, sys: 100 ms, total: 55.1 s
# Wall time: 55 s

# %%
covariate_df_new1.drug_npi_desc_grouped.value_counts()
# Out:
# family_medicine_group        19338
#                              16073
# internal_medicine_group      10070
# emergency/acute_group         7560
# advanced_specialist_group     7277
# OBGYN_group                   3593
# other_group                   2747
# urology_group                 1845
# Name: drug_npi_desc_grouped, dtype: int64

# %%
covariate_df_new1.provider_specialty_available.value_counts()
# Out:
# True     53014
# False    15489
# Name: provider_specialty_available, dtype: int64

# %%
covariate_df_new1.provider_specialty_available =   (covariate_df_new1.drug_npi_desc_grouped!='')

# %%
covariate_df_new1.provider_specialty_available.value_counts()
# Out:
# True     52430
# False    16073
# Name: provider_specialty_available, dtype: int64

# %%
'''n = '1073563987'
r = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')
results_text =json.loads( r.text)'''
# Out:
# "n = '1073563987'\nr = requests.get(f'https://npiregistry.cms.hhs.gov/api//resultsDemo2/?version=2.1&number={n}&pretty=on')\nresults_text =json.loads( r.text)"

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='OBGYN_group'].drug_npi_desc.value_counts()
# Out:
# Obstetrics & Gynecology                                                      2657
# Obstetrics & Gynecology Gynecology                                            537
# Obstetrics & Gynecology Female Pelvic Medicine and Reconstructive Surgery     171
# Advanced Practice Midwife                                                      81
# Obstetrics & Gynecology Obstetrics                                             63
# Obstetrics & Gynecology Reproductive Endocrinology                             24
# Obstetrics & Gynecology Critical Care Medicine                                 23
# Midwife                                                                        22
# Obstetrics & Gynecology Gynecologic Oncology                                    9
# Obstetrics & Gynecology Maternal & Fetal Medicine                               6
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='urology_group'].drug_npi_desc.value_counts()
# Out:
# Urology                                                      1804
# Urology Female Pelvic Medicine and Reconstructive Surgery      41
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='emergency/acute_group'].drug_npi_desc.value_counts()
# Out:
# Emergency Medicine                                    4136
# General Acute Care Hospital                           2854
# Hospitalist                                            391
# Emergency Medicine Emergency Medical Services          148
# Pediatrics Pediatric Emergency Medicine                  8
# General Acute Care Hospital Children                     5
# Emergency Medicine Pediatric Emergency Medicine          5
# Special Hospital                                         4
# Emergency Medicine Hospice and Palliative Medicine       3
# Clinic/Center Emergency Care                             2
# Personal Emergency Response Attendant                    2
# General Acute Care Hospital Rural                        1
# General Acute Care Hospital Critical Access              1
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='other_group'].drug_npi_desc.value_counts().head(40)
# Out:
# Non-Pharmacy Dispensing Site                                      582
# Pediatrics                                                        485
# Specialist                                                        354
# Internal Medicine Nephrology                                      166
# Internal Medicine Infectious Disease                               91
# Surgery                                                            87
# Internal Medicine Pulmonary Disease                                86
# Internal Medicine Cardiovascular Disease                           56
# Internal Medicine Endocrinology, Diabetes & Metabolism             53
# Internal Medicine Gastroenterology                                 51
# Internal Medicine Rheumatology                                     48
# Dermatology                                                        47
# Internal Medicine Hematology & Oncology                            47
# Clinic/Center Urgent Care                                          35
# Student in an Organized Health Care Education/Training Program     35
# Pediatrics Adolescent Medicine                                     35
# Ophthalmology                                                      26
# Psychiatry & Neurology Psychiatry                                  26
# Internal Medicine Allergy & Immunology                             26
# Internal Medicine Hospice and Palliative Medicine                  23
# Internal Medicine Critical Care Medicine                           21
# Orthopaedic Surgery                                                20
# Psychiatry & Neurology Neurology                                   17
# Legal Medicine                                                     16
# Internal Medicine Adolescent Medicine                              14
# Clinic/Center Ambulatory Family Planning Facility                  13
# Thoracic Surgery (Cardiothoracic Vascular Surgery)                 13
# Dentist Oral and Maxillofacial Surgery                             12
# Physical Medicine & Rehabilitation                                 12
# Plastic Surgery                                                    11
# Internal Medicine Medical Oncology                                 11
# Allergy & Immunology                                               11
# Surgery Vascular Surgery                                           11
# Clinic/Center Federally Qualified Health Center (FQHC)             11
# Otolaryngology                                                     10
# Preventive Medicine Occupational Medicine                          10
# Neuromusculoskeletal Medicine & OMM                                 9
# Internal Medicine Interventional Cardiology                         8
# Podiatrist Foot & Ankle Surgery                                     7
# Ophthalmology Retina Specialist                                     7
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='internal_medicine_group'].drug_npi_desc.value_counts()
# Out:
# Internal Medicine                       9769
# Internal Medicine Geriatric Medicine     301
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='family_medicine_group'].drug_npi_desc.value_counts()
# Out:
# Family Medicine                                    18583
# General Practice                                     246
# Family Medicine Sports Medicine                      193
# Family Medicine Geriatric Medicine                   126
# Family Medicine Adult Medicine                       120
# Family Medicine Hospice and Palliative Medicine       39
# Family Medicine Adolescent Medicine                   15
# Family Medicine Addiction Medicine                    14
# Family Medicine Bariatric Medicine                     1
# Family Medicine Sleep Medicine                         1
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='advanced_specialist_group'].drug_npi_desc.value_counts()
# Out:
# Nurse Practitioner Family                                        4325
# Nurse Practitioner                                                679
# Nurse Practitioner Adult Health                                   649
# Physician Assistant                                               587
# Physician Assistant Medical                                       371
# Nurse Practitioner Primary Care                                   171
# Nurse Practitioner Women's Health                                 123
# Nurse Practitioner Obstetrics & Gynecology                        109
# Nurse Practitioner Gerontology                                     63
# Nurse Practitioner Acute Care                                      42
# Nurse Practitioner Pediatrics                                      40
# Registered Nurse Emergency                                         37
# Nurse Practitioner Psych/Mental Health                             19
# Physician Assistant Surgical                                       17
# Nurse Practitioner Community Health                                12
# Clinical Nurse Specialist Family Health                             6
# Registered Nurse                                                    4
# Nurse Practitioner Perinatal                                        4
# Registered Nurse General Practice                                   4
# Clinical Nurse Specialist Psych/Mental Health, Child & Family       4
# Registered Nurse Women's Health Care, Ambulatory                    3
# Registered Nurse Lactation Consultant                               2
# Nurse Practitioner Neonatal                                         2
# Clinical Nurse Specialist Adult Health                              2
# Nurse Practitioner Pediatrics, Critical Care                        1
# Registered Nurse Pediatrics                                         1
# Name: drug_npi_desc, dtype: int64

# %%
covariate_df_new1[covariate_df_new1['drug_npi_desc_grouped']=='family_medicine_group']
# Out:
#        level_0    index  condition_occurrence_id  person_id  \
# 3            3  3828990                455153289        658
# 6            6   243383                 84456435        866
# 8            8  3828990                281762827        903
# 9            9   115391                165986182        906
# 10          10   115391                 96124270        950
# ...        ...      ...                      ...        ...
# 68469    68469   115391                564097251   31075176
# 68470    68470  3828990                326697831   31086860
# 68481    68481   115391                179684509   31858443
# 68491    68491   285902                363012747   32644444
# 68492    68492   243164                545209980   32649281
#
#        condition_concept_id condition_start_date condition_start_datetime  \
# 3                     81902           2019-06-01               2019-06-01
# 6                     81902           2014-06-08               2014-06-08
# 8                     81902           2016-12-05               2016-12-05
# 9                     81902           2015-10-16               2015-10-16
# 10                   194081           2014-07-24               2014-07-24
# ...                     ...                  ...                      ...
# 68469                 81902           2020-10-06               2020-10-06
# 68470              37018854           2017-09-20               2017-09-20
# 68481                 81902           2015-12-22               2015-12-22
# 68491                 81902           2018-03-10               2018-03-10
# 68492                194081           2020-07-12               2020-07-12
#
#       condition_end_date condition_end_datetime  visit_occurrence_id  ...  \
# 3                   None                   None               929640  ...
# 6                   None                   None               933140  ...
# 8                   None                   None               934418  ...
# 9                   None                   None               934656  ...
# 10                  None                   None               935576  ...
# ...                  ...                    ...                  ...  ...
# 68469               None                   None            159254959  ...
# 68470               None                   None            159267356  ...
# 68481               None                   None            159826768  ...
# 68491               None                   None            160407367  ...
# 68492               None                   None            160412014  ...
#
#        inappropriate_12_to_24_mo  nitrofurantoin_most_recent  \
# 3                              0                           1
# 6                              1                           0
# 8                              1                           0
# 9                              0                           0
# 10                             0                           0
# ...                          ...                         ...
# 68469                          0                           0
# 68470                          1                           0
# 68481                          0                           0
# 68491                          1                           0
# 68492                          0                           0
#
#       fosfomycin_most_recent trimethoprim-sulfamethoxazole_most_recent  \
# 3                          0                                         0
# 6                          0                                         0
# 8                          0                                         0
# 9                          0                                         0
# 10                         0                                         0
# ...                      ...                                       ...
# 68469                      0                                         0
# 68470                      0                                         0
# 68481                      0                                         0
# 68491                      0                                         0
# 68492                      0                                         0
#
#       second_line_most_recent  alternatives_most_recent  \
# 3                           0                         0
# 6                           1                         0
# 8                           0                         0
# 9                           0                         0
# 10                          1                         0
# ...                       ...                       ...
# 68469                       0                         1
# 68470                       0                         0
# 68481                       1                         0
# 68491                       0                         0
# 68492                       0                         0
#
#        inappropriate_most_recent    drug_npi_desc  \
# 3                              0  Family Medicine
# 6                              0  Family Medicine
# 8                              1  Family Medicine
# 9                              1  Family Medicine
# 10                             0  Family Medicine
# ...                          ...              ...
# 68469                          0  Family Medicine
# 68470                          1  Family Medicine
# 68481                          0  Family Medicine
# 68491                          1  Family Medicine
# 68492                          1  Family Medicine
#
#       provider_specialty_available  drug_npi_desc_grouped
# 3                             True  family_medicine_group
# 6                             True  family_medicine_group
# 8                             True  family_medicine_group
# 9                             True  family_medicine_group
# 10                            True  family_medicine_group
# ...                            ...                    ...
# 68469                         True  family_medicine_group
# 68470                         True  family_medicine_group
# 68481                         True  family_medicine_group
# 68491                         True  family_medicine_group
# 68492                         True  family_medicine_group
#
# [19338 rows x 82 columns]

# %%
specialties = pd.DataFrame(covariate_df_new1.drug_npi_desc_grouped.value_counts()).index
specialties = specialties.drop('')
specialties_list =[]
for s in list(specialties):
    specialties_list.append('specialty_'+str(s))

#pd.DataFrame(v12.concept_name.value_counts()).head(32)

# %%
temp = covariate_df_new1[['drug_npi_desc_grouped']]
onehot = pd.get_dummies(temp,prefix = 'specialty')

# %%
onehot.loc[:,specialties_list].sum()
# Out:
# specialty_family_medicine_group        19338
# specialty_internal_medicine_group      10070
# specialty_emergency/acute_group         7560
# specialty_advanced_specialist_group     7277
# specialty_OBGYN_group                   3593
# specialty_other_group                   2747
# specialty_urology_group                 1845
# dtype: int64

# %%
covariate_df_new2 = covariate_df_new1.merge(onehot.loc[:,specialties_list],left_index = True,right_index = True)

# %%
covariate_df_new2 = covariate_df_new2.drop(columns = ['drug_npi_desc'])

# %%
covariate_df_new2 = covariate_df_new2.drop(columns = ['drug_npi_desc_grouped'])

# %%
#covariate_df_new2 = covariate_df_new2.rename(columns = {'specialty_Clinic/Center Federally Qualified Health Center (FQHC)':'specialty_Clinic/Center Federally Qualified Health Center'})

# %%
covariate_df_new2 =covariate_df_new2.drop(columns = 'level_0')

# %%
covariate_df_new2.to_sql("{}".format(out_name),con=db.engine, if_exists="replace", schema="cdm_6871_21")

# %%
db.execute("GRANT SELECT ON TABLE cdm_6871_21.{} TO cdm_6871_21;".format(out_name))
# Out:
# Executed 1 SQLs

# %% [markdown]
# # Stop

# %% [markdown]
# ## Analysis

# %%
provider_table[provider_table.drug_npi.isna()].visit_npi_desc.value_counts().head(30)
# Out:
#                                                                              6310
# Clinical Medical Laboratory                                                  3421
# Family Medicine                                                              2207
# Internal Medicine                                                            1182
# Emergency Medicine                                                           1026
# General Acute Care Hospital                                                   893
# Clinic/Center Urgent Care                                                     517
# Obstetrics & Gynecology                                                       352
# Counselor                                                                     316
# Urology                                                                       104
# Pathology Anatomic Pathology & Clinical Pathology                              85
# Pediatrics                                                                     76
# Nurse Practitioner Family                                                      71
# Specialist                                                                     71
# Community/Behavioral Health                                                    54
# Obstetrics & Gynecology Gynecology                                             52
# Student in an Organized Health Care Education/Training Program                 51
# Clinic/Center Emergency Care                                                   49
# Clinic/Center                                                                  41
# General Practice                                                               40
# Social Worker Clinical                                                         40
# Emergency Medicine Emergency Medical Services                                  38
# Surgery                                                                        35
# Clinic/Center Multi-Specialty                                                  31
# Rehabilitation Unit                                                            28
# Internal Medicine Geriatric Medicine                                           28
# Clinic/Center Primary Care                                                     27
# Internal Medicine Cardiovascular Disease                                       27
# Obstetrics & Gynecology Female Pelvic Medicine and Reconstructive Surgery      26
# Family Medicine Geriatric Medicine                                             24
# Name: visit_npi_desc, dtype: int64

# %%
provider_table[provider_table.drug_npi.isna()]
# Out:
#        index   npi drug_npi   visit_npi  condition_occurrence_id  person_id  \
# 0          0  None     None  1912177908                400169196         29
# 2          2  None     None  1205183894                465004090        101
# 4          4  None     None        None                148592964        481
# 5          5  None     None        None                247776427        481
# 20        20  None     None  1902128721                554869223       9964
# ...      ...   ...      ...         ...                      ...        ...
# 79973  83445  None     None  1033107057                301486613   32205287
# 79981  83453  None     None  1043565021                356369082   33341244
# 79982  83454  None     None  1366462459                436711243   33341244
# 79983  83455  None     None  1396131603                540800305   33405322
# 79986  83458  None     None        None                444880147   34177663
#
#        visit_provider_id  provider_id  visit_specialty_concept_id  \
# 0                4239547           -1                         0.0
# 2                4242219           -1                         0.0
# 4                4217804           -1                         0.0
# 5                4217804           -1                         0.0
# 20               4240462           -1                         0.0
# ...                  ...          ...                         ...
# 79973            4261920           -1                         0.0
# 79981            4288319           -1                         0.0
# 79982            4255358           -1                         0.0
# 79983            4714388           -1                  38003845.0
# 79986            4217804           -1                         0.0
#
#        specialty_concept_id   visit_concept_name concept_name  \
# 0                       0.0  No matching concept         None
# 2                       0.0  No matching concept         None
# 4                       0.0  No matching concept         None
# 5                       0.0  No matching concept         None
# 20                      0.0  No matching concept         None
# ...                     ...                  ...          ...
# 79973                   0.0  No matching concept         None
# 79981                   0.0  No matching concept         None
# 79982                   0.0  No matching concept         None
# 79983                   0.0   Emergency Medicine         None
# 79986                   0.0  No matching concept         None
#
#        provider_specialty_available  visit_provider_specialty_available  \
# 0                             False                               False
# 2                             False                               False
# 4                             False                               False
# 5                             False                               False
# 20                            False                               False
# ...                             ...                                 ...
# 79973                         False                               False
# 79981                         False                               False
# 79982                         False                               False
# 79983                         False                                True
# 79986                         False                               False
#
#                      visit_npi_desc drug_npi_desc  npi_same
# 0      Clinic/Center Emergency Care                   False
# 2                Emergency Medicine                   False
# 4                                                     False
# 5                                                     False
# 20        Clinic/Center Urgent Care                   False
# ...                             ...           ...       ...
# 79973       Obstetrics & Gynecology                   False
# 79981   Clinical Medical Laboratory                   False
# 79982               Family Medicine                   False
# 79983            Emergency Medicine                   False
# 79986                                                 False
#
# [17598 rows x 17 columns]

# %%
tmp = provider_table.assign(drug_npi_desc_grouped = '')

i=0
for idx, row in tmp.iterrows():
    desc = row.drug_npi_desc.lower()
    if 'nurse' in desc or 'physician assistant' in desc:
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'advanced_specialist_group'
    elif 'family' in desc and not ('planning' in desc or 'marriage' in desc):
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'family_medicine_group'
    elif 'internal' in desc or 'general practice' in desc:
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'internal_medicine_group'
    elif 'emergency' in desc or 'acute' in desc or 'hospital' in desc:
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'emergency/acute_group'
    elif 'urology' in desc and not('neurology' in desc):
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'urology_group'
    elif 'gynecology' in desc or 'OBG' in desc or 'midwife' in desc:
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'OBGYN_group'
    elif len(desc)>0 :
        tmp.loc[idx,'drug_npi_desc_grouped'] = 'other_group'
    if i %3000 ==0:
        print(i)
        
    i = i+1
# Out:
# 0
# 3000
# 6000
# 9000
# 12000
# 15000
# 18000
# 21000
# 24000
# 27000
# 30000
# 33000
# 36000
# 39000
# 42000
# 45000
# 48000
# 51000
# 54000
# 57000
# 60000
# 63000
# 66000
# 69000
# 72000
# 75000
# 78000

# %%
tmp = tmp.assign(visit_npi_desc_grouped = '')

i=0
for idx, row in tmp.iterrows():
    desc = row.visit_npi_desc.lower()
    if 'nurse' in desc or 'physician assistant' in desc:
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'advanced_specialist_group'
    elif 'family' in desc and not ('planning' in desc or 'marriage' in desc):
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'family_medicine_group'
    elif 'internal' in desc or 'general practice' in desc:
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'internal_medicine_group'
    elif 'emergency' in desc or 'acute' in desc or 'hospital' in desc:
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'emergency/acute_group'
    elif 'urology' in desc and not('neurology' in desc):
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'urology_group'
    elif 'gynecology' in desc or 'OBG' in desc or 'midwife' in desc:
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'OBGYN_group'
    elif len(desc)>0 :
        tmp.loc[idx,'visit_npi_desc_grouped'] = 'other_group'
    if i %3000 ==0:
        print(i)
        
    i = i+1
# Out:
# 0
# 3000
# 6000
# 9000
# 12000
# 15000
# 18000
# 21000
# 24000
# 27000
# 30000
# 33000
# 36000
# 39000
# 42000
# 45000
# 48000
# 51000
# 54000
# 57000
# 60000
# 63000
# 66000
# 69000
# 72000
# 75000
# 78000

# %%
tmp2 = tmp[tmp.drug_npi_desc_grouped != '']

# %%
tmp3 =  tmp2[tmp2.visit_npi_desc_grouped != '']

# %%
tmp3
# Out:
#        index         npi    drug_npi   visit_npi  condition_occurrence_id  \
# 1          1  1609227529  1609227529  1720007123                543518058
# 6          6  1184719445  1184719445  1184719445                206554012
# 7          7  1770577900  1770577900  1770577900                455153289
# 8          8  1427564830  1427564830  1427564830                565954572
# 9          9  1033165360  1033165360  1033165360                329480918
# ...      ...         ...         ...         ...                      ...
# 79985  83457  1235181892  1235181892  1235181892                410361010
# 79987  83459  1376002444  1376002444  1902809940                547287974
# 79988  83460  1912303033  1912303033  1902809940                374486397
# 79989  83461  1922528348  1922528348  1336344399                515586779
# 79990  83462  1669400818  1669400818  1669400818                419945433
#
#        person_id  visit_provider_id  provider_id  visit_specialty_concept_id  \
# 1             35            4259044      4721823                  38003845.0
# 6            649            4248018      4248018                  38003845.0
# 7            658            4257346      4257346                         0.0
# 8            658            4674150      4674150                         0.0
# 9            744            4258814      4258814                  38004474.0
# ...          ...                ...          ...                         ...
# 79985   34041930            4562136      4562136                  38003845.0
# 79987   34234398            4483589      4710740                         0.0
# 79988   34507232            4483589      4575776                         0.0
# 79989   34507232            4272423      4651097                         0.0
# 79990   34528816            4244287      4244287                  38004478.0
#
#        specialty_concept_id   visit_concept_name           concept_name  \
# 1                38004456.0   Emergency Medicine      Internal Medicine
# 6                38003845.0   Emergency Medicine     Emergency Medicine
# 7                       0.0  No matching concept    No matching concept
# 8                       0.0  No matching concept    No matching concept
# 9                38004474.0              Urology                Urology
# ...                     ...                  ...                    ...
# 79985            38003845.0   Emergency Medicine     Emergency Medicine
# 79987                   0.0  No matching concept    No matching concept
# 79988            38004461.0  No matching concept  Obstetrics/Gynecology
# 79989                   0.0  No matching concept    No matching concept
# 79990            38004478.0   Geriatric Medicine     Geriatric Medicine
#
#        provider_specialty_available  visit_provider_specialty_available  \
# 1                              True                                True
# 6                              True                                True
# 7                             False                               False
# 8                             False                               False
# 9                              True                                True
# ...                             ...                                 ...
# 79985                          True                                True
# 79987                         False                               False
# 79988                          True                               False
# 79989                         False                               False
# 79990                          True                                True
#
#                     visit_npi_desc  \
# 1               Emergency Medicine
# 6               Emergency Medicine
# 7                  Family Medicine
# 8       Registered Nurse Emergency
# 9                          Urology
# ...                            ...
# 79985           Emergency Medicine
# 79987  Clinical Medical Laboratory
# 79988  Clinical Medical Laboratory
# 79989              Family Medicine
# 79990            Internal Medicine
#
#                                            drug_npi_desc  npi_same  \
# 1      Student in an Organized Health Care Education/...     False
# 6                                     Emergency Medicine      True
# 7                                        Family Medicine      True
# 8                             Registered Nurse Emergency      True
# 9                                                Urology      True
# ...                                                  ...       ...
# 79985                                 Emergency Medicine      True
# 79987                          Nurse Practitioner Family     False
# 79988                            Obstetrics & Gynecology     False
# 79989                       Non-Pharmacy Dispensing Site     False
# 79990                                  Internal Medicine      True
#
#            drug_npi_desc_grouped     visit_npi_desc_grouped
# 1                    other_group      emergency/acute_group
# 6          emergency/acute_group      emergency/acute_group
# 7          family_medicine_group      family_medicine_group
# 8      advanced_specialist_group  advanced_specialist_group
# 9                  urology_group              urology_group
# ...                          ...                        ...
# 79985      emergency/acute_group      emergency/acute_group
# 79987  advanced_specialist_group                other_group
# 79988                OBGYN_group                other_group
# 79989                other_group      family_medicine_group
# 79990    internal_medicine_group    internal_medicine_group
#
# [54620 rows x 19 columns]

# %%
df = tmp3[['drug_npi_desc_grouped','visit_npi_desc_grouped']]

# %%
df
# Out:
#            drug_npi_desc_grouped     visit_npi_desc_grouped
# 1                    other_group      emergency/acute_group
# 6          emergency/acute_group      emergency/acute_group
# 7          family_medicine_group      family_medicine_group
# 8      advanced_specialist_group  advanced_specialist_group
# 9                  urology_group              urology_group
# ...                          ...                        ...
# 79985      emergency/acute_group      emergency/acute_group
# 79987  advanced_specialist_group                other_group
# 79988                OBGYN_group                other_group
# 79989                other_group      family_medicine_group
# 79990    internal_medicine_group    internal_medicine_group
#
# [54620 rows x 2 columns]

# %%
final = df.groupby(['drug_npi_desc_grouped','visit_npi_desc_grouped']).size()

# %%
temp = pd.DataFrame(final)

# %%
temp
# Out:
#                                                         0
# drug_npi_desc_grouped     visit_npi_desc_grouped
# OBGYN_group               OBGYN_group                1500
#                           advanced_specialist_group    13
#                           emergency/acute_group       153
#                           family_medicine_group        36
#                           internal_medicine_group      31
#                           other_group                2137
#                           urology_group                 7
# advanced_specialist_group OBGYN_group                  86
#                           advanced_specialist_group  2874
#                           emergency/acute_group       500
#                           family_medicine_group       800
#                           internal_medicine_group     421
#                           other_group                2765
#                           urology_group                36
# emergency/acute_group     OBGYN_group                   8
#                           advanced_specialist_group    49
#                           emergency/acute_group      6274
#                           family_medicine_group       198
#                           internal_medicine_group     428
#                           other_group                1083
#                           urology_group                22
# family_medicine_group     OBGYN_group                  23
#                           advanced_specialist_group    76
#                           emergency/acute_group       842
#                           family_medicine_group      9948
#                           internal_medicine_group     231
#                           other_group                7974
#                           urology_group                30
# internal_medicine_group   OBGYN_group                  11
#                           advanced_specialist_group    53
#                           emergency/acute_group      1349
#                           family_medicine_group       194
#                           internal_medicine_group    5499
#                           other_group                4039
#                           urology_group                52
# other_group               OBGYN_group                  31
#                           advanced_specialist_group    16
#                           emergency/acute_group       304
#                           family_medicine_group       392
#                           internal_medicine_group     221
#                           other_group                2406
#                           urology_group                19
# urology_group             advanced_specialist_group     4
#                           emergency/acute_group        98
#                           family_medicine_group        19
#                           internal_medicine_group      13
#                           other_group                 686
#                           urology_group               669

# %%
temp.sort_values(by = (0),ascending = False).head(50)
# Out:
#                                                         0
# drug_npi_desc_grouped     visit_npi_desc_grouped
# family_medicine_group     family_medicine_group      9948
#                           other_group                7974
# emergency/acute_group     emergency/acute_group      6274
# internal_medicine_group   internal_medicine_group    5499
#                           other_group                4039
# advanced_specialist_group advanced_specialist_group  2874
#                           other_group                2765
# other_group               other_group                2406
# OBGYN_group               other_group                2137
#                           OBGYN_group                1500
# internal_medicine_group   emergency/acute_group      1349
# emergency/acute_group     other_group                1083
# family_medicine_group     emergency/acute_group       842
# advanced_specialist_group family_medicine_group       800
# urology_group             other_group                 686
#                           urology_group               669
# advanced_specialist_group emergency/acute_group       500
# emergency/acute_group     internal_medicine_group     428
# advanced_specialist_group internal_medicine_group     421
# other_group               family_medicine_group       392
#                           emergency/acute_group       304
# family_medicine_group     internal_medicine_group     231
# other_group               internal_medicine_group     221
# emergency/acute_group     family_medicine_group       198
# internal_medicine_group   family_medicine_group       194
# OBGYN_group               emergency/acute_group       153
# urology_group             emergency/acute_group        98
# advanced_specialist_group OBGYN_group                  86
# family_medicine_group     advanced_specialist_group    76
# internal_medicine_group   advanced_specialist_group    53
#                           urology_group                52
# emergency/acute_group     advanced_specialist_group    49
# advanced_specialist_group urology_group                36
# OBGYN_group               family_medicine_group        36
# other_group               OBGYN_group                  31
# OBGYN_group               internal_medicine_group      31
# family_medicine_group     urology_group                30
#                           OBGYN_group                  23
# emergency/acute_group     urology_group                22
# other_group               urology_group                19
# urology_group             family_medicine_group        19
# other_group               advanced_specialist_group    16
# OBGYN_group               advanced_specialist_group    13
# urology_group             internal_medicine_group      13
# internal_medicine_group   OBGYN_group                  11
# emergency/acute_group     OBGYN_group                   8
# OBGYN_group               urology_group                 7
# urology_group             advanced_specialist_group     4
